# %% [markdown]
# <a href="https://colab.research.google.com/github/gracemaria321/AI-for-CyberSecurity/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This project requires Python 3.7 or above.
# It also requires Scikit-Learn ≥ 1.0.1

# %%
import sys
assert sys.version_info >= (3, 7)

from packaging import version
import sklearn
assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

# %% [markdown]
# Mount Google Drive Code
#
# Read the Data from the Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Data Analysis Key Findings
#
# *   **Initial Mounting Failure**: An initial attempt to mount Google Drive failed because an incorrect mount path (a Google Drive file URL) was provided instead of a local directory path.
# *   **Successful Drive Mounting**: After correcting the mount path to `/content/drive`, the Google Drive was successfully mounted. The system confirmed, "Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True)," indicating a successful operation or a pre-existing mounted state.

# %% [markdown]
# Unzip Dataset

# %%
import os
import zipfile

# The actual path to your .zip file in Google Drive
zip_file_path = '/content/drive/MyDrive/Colab Notebooks/Final Project.zip'
# The desired directory to extract the contents
extraction_dir = '/content/unzipped_data'

# Create the extraction directory if it doesn't exist
os.makedirs(extraction_dir, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_dir)

print(f"Successfully unzipped '{zip_file_path}' to '{extraction_dir}'")
# Out:
# Successfully unzipped '/content/drive/MyDrive/Colab Notebooks/Final Project.zip' to '/content/unzipped_data'

# %% [markdown]
# List the contents of the directory where the dataset was unzipped to identify the main data files.

# %%
import os

# The directory where the files were extracted
extraction_dir = '/content/unzipped_data'

# List all files and directories in the extraction directory
print(f"Contents of '{extraction_dir}':")
for root, dirs, files in os.walk(extraction_dir):
    for name in files:
        print(os.path.join(root, name))
    for name in dirs:
        print(os.path.join(root, name))
# Out:
# Contents of '/content/unzipped_data':
# /content/unzipped_data/Final Project
# /content/unzipped_data/Final Project/JavascriptSamplesObfuscated
# /content/unzipped_data/Final Project/JavascriptSamples
# /content/unzipped_data/Final Project/JavascriptSamplesObfuscated/date-utils-obfuscated.js
# /content/unzipped_data/Final Project/JavascriptSamplesObfuscated/child-process-message-and-exit-obfuscated.js
# /content/unzipped_data/Final Project/JavascriptSamplesObfuscated/angular-locale_sr-latn-xk-obfuscated.js
# /content/unzipped_data/Final Project/JavascriptSamplesObfuscated/angular-locale_fa-obfuscated.js
# /content/unzipped_data/Final Project/JavascriptSamplesObfuscated/angular-locale_mer-obfuscated.js
# /content/unzipped_data/Final Project/JavascriptSamplesObfuscated/angular-locale_kk-obfuscated.js
# /content/unzipped_data/Final Project/JavascriptSamplesObfuscated/default-obfuscated.js
# /content/unzipped_data/Final Project/JavascriptSamplesObfuscated/interval-obfuscated.js
# ...
